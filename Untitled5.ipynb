# %%
# Quantium Retail Analytics — Task 2  
### Trial Layout Evaluation (Stores 77, 86, 88)

This notebook contains the full analysis for Task 2:
- Selecting control stores using pre-trial monthly metrics  
- Comparing trial vs control during trial period  
- Identifying statistical significance  
- Recommending which trial stores should roll out the layout

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# show plots in notebook
# %matplotlib inline

# Load your clean Task 1 data
df = pd.read_csv("QVI_data.csv")

df.head()
